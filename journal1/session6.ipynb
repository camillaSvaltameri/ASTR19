# %%
import math

def sin(x):
    return math.sin(x)

# %% [markdown]
# This function returns the sine value of a given value x

# %%
def cos(x):
    return math

# %% [markdown]
# This function returns the cosine value of a given value x

# %%
num_points = 1000
start = 0
end = 2 * math.pi
step = (end - start) / (num_points - 1)

x_vals = []
sin_vals = []
cos_vals = []

for i in range(num_points):
    x = start + i * step
    x_vals.append(x)
    sin_vals.append(sin(x))
    cos_vals.append(cos(x))

# %% [markdown]
# Prints out the first 10 values of x, sine, and cosine into a table
